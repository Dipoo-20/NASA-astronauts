# %% [markdown]
# # Mini Project
# Dataset of NASA astronauts
# Yashsvi Sarve(S1032211925)
# Dipali Gupta (S1032210087)
# Class F.Y.M.Tech [VLSI & ES]

# %%
import pandas as pd
df= pd.read_csv(r"D:\college\da\nasa\astronauts.csv")
df
# Out:
#                       Name    Year  Group   Status Birth Date  \
# 0          Joseph M. Acaba  2004.0   19.0   Active  5/17/1967
# 1           Loren W. Acton     NaN    NaN  Retired   3/7/1936
# 2         James C. Adamson  1984.0   10.0  Retired   3/3/1946
# 3          Thomas D. Akers  1987.0   12.0  Retired  5/20/1951
# 4              Buzz Aldrin  1963.0    3.0  Retired  1/20/1930
# ..                     ...     ...    ...      ...        ...
# 352          David A. Wolf  1990.0   13.0  Retired  8/23/1956
# 353  Neil W. Woodward III   1998.0   17.0  Retired  7/26/1962
# 354       Alfred M. Worden  1966.0    5.0  Retired   2/7/1932
# 355          John W. Young  1962.0    2.0  Retired  9/24/1930
# 356        George D. Zamka  1998.0   17.0  Retired  6/29/1962
#
#            Birth Place Gender  \
# 0        Inglewood, CA   Male
# 1         Lewiston, MT   Male
# 2           Warsaw, NY   Male
# 3        St. Louis, MO   Male
# 4        Montclair, NJ   Male
# ..                 ...    ...
# ...

# %%
#Q1 Check if there are any duplicate records

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Name, Year, Group, Status, Birth Date, Birth Place, Gender, Alma Mater, Undergraduate Major, Graduate Major, Military Rank, Military Branch, Space Flights, Space Flight (hr), Space Walks, Space Walks (hr), Missions, Death Date, Death Mission]
# Index: []

# %%
#Q2 Check if there are any values missing and if yes how many and show it with a heat map

# %%
df.isnull()
# Out:
#       Name   Year  Group  Status  Birth Date  Birth Place  Gender  Alma Mater  \
# 0    False  False  False   False       False        False   False       False
# 1    False   True   True   False       False        False   False       False
# 2    False  False  False   False       False        False   False       False
# 3    False  False  False   False       False        False   False       False
# 4    False  False  False   False       False        False   False       False
# ..     ...    ...    ...     ...         ...          ...     ...         ...
# 352  False  False  False   False       False        False   False       False
# 353  False  False  False   False       False        False   False       False
# 354  False  False  False   False       False        False   False       False
# 355  False  False  False   False       False        False   False       False
# 356  False  False  False   False       False        False   False       False
#
# ...

# %%
df.isnull().sum()
# Out:
# Name                     0
# Year                    27
# Group                   27
# Status                   0
# Birth Date               0
# Birth Place              0
# Gender                   0
# Alma Mater               1
# Undergraduate Major     22
# Graduate Major          59
# Military Rank          150
# Military Branch        146
# Space Flights            0
# Space Flight (hr)        0
# Space Walks              0
# Space Walks (hr)         0
# Missions                23
# Death Date             305
# Death Mission          341
# dtype: int64

# %%
import seaborn as sns
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
#Q3 Count the number of active, deceased, retired astronauts

# %%
df.groupby('Status').Status.count()
# Out:
# Status
# Active         50
# Deceased       51
# Management     36
# Retired       220
# Name: Status, dtype: int64

# %%
#Q4 Display the male female ratio with a bar graph

# %%
df.groupby('Gender').Gender.count()
# Out:
# Gender
# Female     50
# Male      307
# Name: Gender, dtype: int64

# %%
sns.countplot(df['Gender'])
# Out:
# D:\college\da\theory\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
#Q5 Display the names of astronauts who did mechanical engineering as undergraduate major

# %%
df.head(2)
# Out:
#               Name    Year  Group   Status Birth Date    Birth Place Gender  \
# 0  Joseph M. Acaba  2004.0   19.0   Active  5/17/1967  Inglewood, CA   Male
# 1   Loren W. Acton     NaN    NaN  Retired   3/7/1936   Lewiston, MT   Male
#
#                                           Alma Mater  Undergraduate Major  \
# 0  University of California-Santa Barbara; Univer...              Geology
# 1   Montana State University; University of Colorado  Engineering Physics
#
#   Graduate Major Military Rank Military Branch  Space Flights  \
# 0        Geology           NaN             NaN              2
# 1  Solar Physics           NaN             NaN              1
#
#    Space Flight (hr)  Space Walks  Space Walks (hr)  \
# 0               3307            2              13.0
# 1                190            0               0.0
#
#                                  Missions Death Date Death Mission
# 0  STS-119 (Discovery), ISS-31/32 (Soyuz)        NaN           NaN
# ...

# %%
df[df['Undergraduate Major']=='Mechanical Engineering']['Name']
# Out:
# 4                          Buzz Aldrin
# 5                      Andrew M. Allen
# 16                    Jeffrey S. Ashby
# 18                     James P. Bagian
# 46                        John S. Bull
# 51                   Fernando Caldeiro
# 57                      Gerald P. Carr
# 65              Franklin R. Chang-Diaz
# 74                 Kenneth D. Cockrell
# 103                     John M. Fabian
# 104            Christopher J. Ferguson
# 115                  Michael E. Fossum
# 118                C. Gordon Fullerton
# 140                  Virgil I. Grissom
# 149                      Terry J. Hart
# 170                    Rick D. Husband
# 244                    Karen L. Nyberg
# 249                     John D. Olivas
# 272                   Paul W. Richards
# 279                      Jerry L. Ross
# 306    Heidemarie M. Stefanyshyn-Piper
# 309              Frederick W. Sturckow
# 312               John L. Swigert Jr.
# 313                     Daniel M. Tani
# ...

# %%
#Q6 Display the names of astronauts who are actively working in US navy

# %%
df[df['Military Branch']=='US Navy']['Name']
# Out:
# 11                Dominic A. Antonelli
# 34                    Stephen G. Bowen
# 36               Charles E. Brady Jr.
# 42                      David M. Brown
# 58           Manley Lanier Carter Jr.
# 60              Christopher J. Cassidy
# 63                    Roger B. Chaffee
# 70                     Laurel B. Clark
# 145                     Kenneth T. Ham
# 222                  William C. McCool
# 235                       Lee M. Morin
# 264                 Alan G. Poindexter
# 301                   Michael J. Smith
# 306    Heidemarie M. Stefanyshyn-Piper
# 318                  Stephen D. Thorne
# 321                    Pierre J. Thuot
# 322                    Scott D. Tingle
# 347                 Sunita L. Williams
# 348                   Barry E. Wilmore
# 350                    G. Reid Wiseman
# 353              Neil W. Woodward III
# Name: Name, dtype: object

# %%
#Q7 Display number of Astronauts who had a military rank of Colonel

# %%
df[df['Military Rank']=='Colonel']['Name'].count()
# Out:
# 94

# %%
#Q8 Map alive to 1 and deceased to 0.

# %%
dcl=[]
for cv in df['Status']:
    if cv=='Deceased':
        dcl.append(0)
    else:
        dcl.append(1)
df['classify']=dcl
df['classify']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 352    1
# 353    1
# 354    1
# 355    1
# 356    1
# Name: classify, Length: 357, dtype: int64

# %%
#9 Display names of astronauts who went for more than two space walks

# %%
df[df['Space Walks']> 2]['Name']
# Out:
# 3          Thomas D. Akers
# 9      Clayton C. Anderson
# 22         Daniel T. Barry
# 25            Alan L. Bean
# 26       Robert L. Behnken
#               ...
# 347     Sunita L. Williams
# 348       Barry E. Wilmore
# 351     Peter J. K. Wisoff
# 352          David A. Wolf
# 355          John W. Young
# Name: Name, Length: 76, dtype: object

# %%
#10 Display all mission accomplished

# %%
df['Missions']
# Out:
# 0                 STS-119 (Discovery), ISS-31/32 (Soyuz)
# 1                                  STS 51-F (Challenger)
# 2                   STS-28 (Columbia), STS-43 (Atlantis)
# 3      STS-41 (Discovery), STS-49 (Endeavor), STS-61 ...
# 4                                   Gemini 12, Apollo 11
#                              ...
# 352    STS-58 (Columbia). STS-86/89 (Atlantis/Endeavo...
# 353                                                  NaN
# 354                                            Apollo 15
# 355    Gemini 3, Gemini 10, Apollo 10, Apollo 16, STS...
# 356              STS-120 (Discovery), STS-130 (Endeavor)
# Name: Missions, Length: 357, dtype: object
